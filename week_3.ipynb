# %% [markdown]
# <a href="https://colab.research.google.com/github/2403A51355/sample/blob/main/week_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

category=["Electronics","clothing","home appliances","groceries"]
units=[350,220,150,500]
plt.figure(figsize=(10, 6))
colors = ['purple', 'lightcoral', 'forestgreen', 'gold']
plt.bar(df['Category'], df['Sales (Units)'], color=colors)
plt.xlabel('Product Category')
plt.ylabel('Units Sold')
plt.title('Total Units Sold by Product Category')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
